# %%
# Load and save small 100x100m section of the large height data as numpy array

# %%
import pandas
x = pandas.read_csv("/home/julian/data/expodata/ALS_OOe/DGM_1m.asc", skiprows=6, sep=" ")

# %%
d = x.iloc[100:200, 100:200]
from matplotlib import pyplot as plt
# %matplotlib inline
plt.imshow(d)

# %%
for i in range(10):
    d.iloc[i].plot()

# %%
numpy.save('hundred.npy', d.to_numpy())
